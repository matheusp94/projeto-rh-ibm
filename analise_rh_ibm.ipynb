# %% [markdown]
# # Introdução

# %% [markdown]
# Análise abaixo feita com dados do rh da IBM disponibilizados no site https://www.kaggle.com/datasets/pavansubhasht/ibm-hr-analytics-attrition-dataset/.com. Buscamos entender o perfil das pessoas que deixam a empresa. Tal informação pode ser relevante para prevenir demições, reduzir custos operacionais e até melhorar a satisfação dos empregados, o que pode aumentar a produtividade da empresa.

# %% [markdown]
# Hipoteses a serem exploradas:
#
# - Existe disparidade salarial entre homens e mulheres?
# - Há evidência de que gênero tenha impacto no atrito entre funcionário e empresa?
# - Qual relação entre salário e departamento em que o funcionário atua?
#
# <i>Proposta:
# - analisar o dataset (estrutura);
# - Análise univariada;
# - análise bivariada;</i>

# %%
#bibliotecas

import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# **Dataset**

# %%
rh = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
rh.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
rh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
rh.shape
# Out:
# (1470, 35)

# %%
rh.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# # Análise univariada

# %%
_ = plt.hist(rh.Age)
_ = plt.title('Histograma de Idade')

# %%
_ = plt.hist(rh.MonthlyIncome)
_ = plt.title('Histograma de Salario')

# %%
rh.Gender.value_counts(1)
# Out:
# Male      0.6
# Female    0.4
# Name: Gender, dtype: float64

# %% [markdown]
# Por ser uma empresa que contrata muitas pessoas da área de STEM, é esperado que tenhamos mais funcionários homens.

# %%
rh.EducationField.value_counts(1)
# Out:
# Life Sciences       0.412245
# Medical             0.315646
# Marketing           0.108163
# Technical Degree    0.089796
# Other               0.055782
# Human Resources     0.018367
# Name: EducationField, dtype: float64

# %%
_ = rh.EducationField.value_counts(1).plot.bar()
_ = plt.title('Headcount por campo educacional')

# %% [markdown]
# Percebemos que a maioria dos funcionpários é formada na  área de Life Sciences. Na sequencia temos funcionários da área Medical. A área com menos funcionários é a de Humans Resources.

# %% [markdown]
# # Análise bivariada

# %%
_ = sns.boxplot(x='Gender', y='MonthlyIncome', data=rh)

# %%
_ = sns.scatterplot(x='YearsAtCompany', y='MonthlyIncome', data = rh)

# %%
rh.corr()
# Out:
# <ipython-input-16-7f056371a3a4>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   rh.corr()
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# ...

# %%
# lista de variáveis
raw_data = ['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
            'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
            'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
            'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
            'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
            'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
            'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
            'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
            'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
            'YearsWithCurrManager']

# matriz de correlação
corrmat = rh[raw_data].corr()

# configurando tamanho do plot
fig = plt.figure(figsize=(22, 12))

# mascarando a parte superior do triângulo pois a matriz é simétrica (repetitiva)
mask = np.triu(np.ones_like(corrmat, dtype=bool))

# ajustando a disposição dos números
annot_kws = {"size": 7}  # tamanho da fonte dos rótulos

# ajustando o espaçamento entre os quadrados e usando um mapa de cores diferente (cmap)
sns.heatmap(corrmat, vmax=0.8, mask=mask, square=True, annot=True, annot_kws=annot_kws,
            linewidths=0.5, cmap="coolwarm")

plt.show()
# Out:
# <ipython-input-23-e2f911c5c1cb>:14: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmat = rh[raw_data].corr()
